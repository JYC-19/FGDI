# %%
import matplotlib.pyplot as plt

val_accurate_list = [0.960699865410498, 0.9707235787989489, 0.9796193039800039, 0.9861180542203423, 0.9895020188425303, 0.9905018265718131, 0.9919759020701148, 0.9918861757354355, 0.9919374479266808, 0.9930141639428315, 0.9935397039030955, 0.9935012497596616, 0.9934243414727937, 0.9927578029866051, 0.9947189643017369, 0.9938345190027559, 0.9941421521502275, 0.9939883355764917, 0.9943856950586426, 0.9943856950586426]
iterations = range(1, len(val_accurate_list) + 1)

plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
plt.xlabel('Epoch', fontsize=22)
plt.ylabel('Accuracy', fontsize=22)
plt.title("CICIOT22 dataset", fontsize=22)
plt.tick_params(axis='x', labelsize=18)  
plt.tick_params(axis='y', labelsize=22) 
plt.xticks(range(0, len(val_accurate_list)+1, 2)) 
plt.ylim(0.8, 1.0)
plt.subplots_adjust(left=0.2)
plt.subplots_adjust(bottom=0.15)
plt.grid(False)
plt.savefig('Accurate_plot_CICIOT.png')
plt.show()
