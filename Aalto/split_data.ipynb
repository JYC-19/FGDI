# %%
import os
from shutil import copy, rmtree
import random


def mk_file(file_path: str):
    if os.path.exists(file_path):
        rmtree(file_path)
    os.makedirs(file_path)


def main():
    random.seed(0)

    split_rate = 0.2

    cwd = os.getcwd()
    data_root = os.path.join(cwd, "features")
    origin_flower_path = os.path.join(data_root, "npy")
    assert os.path.exists(origin_flower_path), "path '{}' does not exist.".format(origin_flower_path)

    flower_class = [cla for cla in os.listdir(origin_flower_path)
                    if os.path.isdir(os.path.join(origin_flower_path, cla))]

    train_root = os.path.join(data_root, "train_npy")
    mk_file(train_root)
    for cla in flower_class:
        mk_file(os.path.join(train_root, cla))

    val_root = os.path.join(data_root, "val_npy")
    mk_file(val_root)
    for cla in flower_class:
        mk_file(os.path.join(val_root, cla))

    for cla in flower_class:
        cla_path = os.path.join(origin_flower_path, cla)
        images = os.listdir(cla_path)
        num = len(images)
        eval_index = random.sample(images, k=int(num*split_rate))
        for index, image in enumerate(images):
            if image in eval_index:
                image_path = os.path.join(cla_path, image)
                new_path = os.path.join(val_root, cla)
                copy(image_path, new_path)
            else:
                image_path = os.path.join(cla_path, image)
                new_path = os.path.join(train_root, cla)
                copy(image_path, new_path)
            print("\r[{}] processing [{}/{}]".format(cla, index+1, num), end="")
        print()

    print("processing done!")


if __name__ == '__main__':
    main()
# Out:
# [Aria] processing [362/362]
# [D-LinkCam] processing [6194/6194]
# [D-LinkDayCam] processing [1023/1023]
# [D-LinkDoorSensor] processing [1892/1892]
# [D-LinkHomeHub] processing [8499/8499]
# [D-LinkSensor] processing [6507/6507]
# [D-LinkSiren] processing [6139/6139]
# [D-LinkSwitch] processing [6474/6474]
# [D-LinkWaterSensor] processing [6381/6381]
# [EdimaxCam1] processing [468/468]
# [EdimaxCam2] processing [317/317]
# [EdimaxPlug1101W] processing [1105/1105]
# [EdimaxPlug2101W] processing [955/955]
# [EdnetCam1] processing [172/172]
# [EdnetCam2] processing [153/153]
# [EdnetGateway] processing [643/643]
# [HomeMaticPlug] processing [611/611]
# [HueBridge] processing [13801/13801]
# [HueSwitch] processing [18448/18448]
# [iKettle2] processing [65/65]
# [Lightify] processing [4071/4071]
# [MAXGateway] processing [535/535]
# [SmarterCoffee] processing [65/65]
# [TP-LinkPlugHS100] processing [626/626]
# [TP-LinkPlugHS110] processing [593/593]
# [WeMoInsightSwitch] processing [4105/4105]
# [WeMoInsightSwitch2] processing [1703/1703]
# [WeMoLink] processing [6585/6585]
# [WeMoSwitch] processing [3503/3503]
# [WeMoSwitch2] processing [909/909]
# [Withings] processing [632/632]
# processing done!
