# %%
import torch.nn as nn
import torch


class AlexNet(nn.Module):
    def __init__(self, num_classes=40, init_weights=False):
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv1d(1, 48, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2),
            nn.Conv1d(48, 128, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2),
            nn.Conv1d(128, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv1d(192, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv1d(192, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            nn.Linear(5888, 2048),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(2048, 2048),
            nn.ReLU(inplace=True),
            nn.Linear(2048, num_classes),
        )
        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, start_dim=1)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv1d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np

def plot_matrix(conf_matrix, dev_list, save_path):
    plt.figure(figsize=(20, 16), dpi=300)
    plt.imshow(conf_matrix, cmap=plt.cm.Blues, interpolation='nearest')
    plt.title('Confusion Matrix')
    plt.colorbar()

    thresh = conf_matrix.max() / 2.
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            plt.text(j, i, conf_matrix[i, j],
                     ha="center", va="center",
                     color="white" if conf_matrix[i, j] > thresh else "black", fontsize=8)

    tick_marks = np.arange(len(dev_list))
    plt.xticks(tick_marks, dev_list, fontsize=8)
    plt.yticks(tick_marks, dev_list, fontsize=8)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

    plt.gca().set_aspect(aspect='equal')

    plt.savefig(save_path)
    plt.show()

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
import numpy as np
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.categories = sorted(os.listdir(data_dir))
        self.data = []
        self.transform = transform
        for category in self.categories:
            category_dir = os.path.join(data_dir, category)
            category_data = sorted(os.listdir(category_dir))
            self.data.extend([(os.path.join(category_dir, file), self.categories.index(category)) for file in category_data])

    def __getitem__(self, index):
        file_path, label = self.data[index]
        data = np.load(file_path)
        image = Image.fromarray(data.astype(np.uint8))
        image = transform(image)
        return image, label

    def __len__(self):
        return len(self.data)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("using {} device.".format(device))

transform = transforms.Compose([ transforms.Grayscale(num_output_channels = 1),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.5), (0.5))])

train_dataset = CustomDataset("features/train_npy",transform=transform)
train_num = len(train_dataset)
dev_list = train_dataset.categories

batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=batch_size, shuffle=True,
                                               num_workers=0)

validate_dataset = CustomDataset("features/val_npy",transform=transform)
val_num = len(validate_dataset)
validate_loader = torch.utils.data.DataLoader(validate_dataset,
                                                  batch_size=batch_size, shuffle=False,
                                                  num_workers=0)

print("using {} images for training, {} images for validation.".format(train_num, val_num))

net = AlexNet(num_classes=31, init_weights=True)
net.to(device)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

epochs = 100
save_path = './AlexNet_parameters.pth'
best_f1 = 0.0
train_accurate_list = []
val_accurate_list = []
f1_list = []
recall_list = []

for epoch in range(epochs):
    net.train()
    running_loss = 0.0
    train_acc = 0.0
    for step, data in enumerate(train_loader, start=0):
        images, labels = data
        images = images.reshape(images.shape[0], 1, 1503)
        optimizer.zero_grad()
        outputs = net(images.to(device))
        predict_y = torch.max(outputs, dim=1)[1]
        train_acc += torch.eq(predict_y, labels.to(device)).sum().item()
        loss = loss_function(outputs,labels.to(device))
        loss.backward()
        optimizer.step()


        running_loss += loss.item()
        rate = (step + 1) / len(train_loader)
        a = "*" * int(rate * 50)
        b = "." * int((1 - rate) * 50)
        print("\rtrain loss:{:^3.0f}%[{}->{}]{:.3f}".format(int(rate * 100), a, b, loss), end="")
    print()
    train_accurate = train_acc / train_num
    train_accurate_list.append(train_accurate)

    net.eval()
    acc = 0.0  
    val = torch.tensor([])
    pre = torch.tensor([])
    with torch.no_grad():
        for val_data in validate_loader:
            val_images, val_labels = val_data
            val_images = val_images.reshape(val_images.shape[0], 1, 1503)
            outputs = net(val_images.to(device))
            predict_y = torch.max(outputs, dim=1)[1]
            pre = torch.cat([pre.to(device), predict_y.to(device)])
            val = torch.cat([val.to(device), val_labels.to(device)])
            acc += torch.eq(predict_y, val_labels.to(device)).sum().item()
    val_accurate = acc / val_num
    val_accurate_list.append(val_accurate)
    f1 = f1_score(val.cpu(), pre.cpu(), average='macro')
    recall = recall_score(val.cpu(), pre.cpu(), average='macro')
    f1_list.append(f1)
    recall_list.append(recall)
    if f1 > best_f1:
        best_f1 = f1
        best_pre = pre
        best_val = val
        torch.save(net.state_dict(), save_path)
        torch.save(best_pre, 'pre_val_label/best_pre_AlexNet.pt')
        torch.save(best_val, 'pre_val_label/best_val_AlexNet.pt')
    print('[epoch %d] train_loss: %.3f train_accuracy: %.3f val_accuracy: %.3f  recall: %.3f  f1: %.3f' %
              (epoch + 1, running_loss / step, train_accurate, val_accurate, recall, f1))
    with open("AlexNet_result_npy.txt", 'a') as file:
        file.write("[epoch " + str(epoch + 1) + "]" + "  " + "train_accuracy:" + str(train_accurate) + "  " + "val_accuracy:" + str(val_accurate) + "  " + "recall:" + str(recall) + "  " + "f1:" + str(f1) + '\n')
print('Finished Training')

iterations = range(1, len(train_accurate_list) + 1)
with open("AlexNet_npy_plt_data.txt", 'a') as file:
    file.write("iterations:" + str(iterations) +
               "train_accurate_list:" + str(train_accurate_list) +
               "val_accurate_list:" + str(val_accurate_list) +
               "f1_list:" + str(f1_list) +
               "recall_list:" + str(recall_list) +
               "dev_list:" + str(dev_list) + '\n')
conf_matrix = confusion_matrix(best_val.cpu(),best_pre.cpu())
plot_matrix(conf_matrix,dev_list,"AlexNet_confusion_matrix_npy.png")
# Out:
# using cuda:0 device.
# using 82841 images for training, 20695 images for validation.
# train loss:100%[**************************************************->]1.017
# [epoch 1] train_loss: 1.132 train_accuracy: 0.582 val_accuracy: 0.693  recall: 0.541  f1: 0.527
# train loss:100%[**************************************************->]0.896
# [epoch 2] train_loss: 0.740 train_accuracy: 0.699 val_accuracy: 0.724  recall: 0.593  f1: 0.587
# train loss:100%[**************************************************->]0.762
# [epoch 3] train_loss: 0.646 train_accuracy: 0.740 val_accuracy: 0.770  recall: 0.631  f1: 0.633
# train loss:100%[**************************************************->]0.776
# [epoch 4] train_loss: 0.569 train_accuracy: 0.775 val_accuracy: 0.799  recall: 0.671  f1: 0.681
# train loss:100%[**************************************************->]0.422
# [epoch 5] train_loss: 0.516 train_accuracy: 0.798 val_accuracy: 0.807  recall: 0.676  f1: 0.683
# train loss:100%[**************************************************->]0.309
# [epoch 6] train_loss: 0.478 train_accuracy: 0.813 val_accuracy: 0.831  recall: 0.720  f1: 0.738
# train loss:100%[**************************************************->]0.291
# [epoch 7] train_loss: 0.439 train_accuracy: 0.829 val_accuracy: 0.834  recall: 0.702  f1: 0.712
# train loss:100%[**************************************************->]0.118
# [epoch 8] train_loss: 0.430 train_accuracy: 0.839 val_accuracy: 0.862  recall: 0.737  f1: 0.748
# train loss:100%[**************************************************->]0.363
# [epoch 9] train_loss: 0.399 train_accuracy: 0.849 val_accuracy: 0.848  recall: 0.717  f1: 0.715
# train loss:100%[**************************************************->]0.372
# [epoch 10] train_loss: 0.383 train_accuracy: 0.859 val_accuracy: 0.861  recall: 0.718  f1: 0.719
# train loss:100%[**************************************************->]0.756
# [epoch 11] train_loss: 0.358 train_accuracy: 0.869 val_accuracy: 0.878  recall: 0.760  f1: 0.777
# train loss:100%[**************************************************->]0.303
# [epoch 12] train_loss: 0.354 train_accuracy: 0.873 val_accuracy: 0.882  recall: 0.776  f1: 0.794
# train loss:100%[**************************************************->]0.204
# [epoch 13] train_loss: 0.343 train_accuracy: 0.879 val_accuracy: 0.886  recall: 0.755  f1: 0.760
# train loss:100%[**************************************************->]0.043
# [epoch 14] train_loss: 0.350 train_accuracy: 0.880 val_accuracy: 0.895  recall: 0.779  f1: 0.790
# train loss:100%[**************************************************->]0.411
# [epoch 15] train_loss: 0.314 train_accuracy: 0.892 val_accuracy: 0.876  recall: 0.751  f1: 0.750
# train loss:100%[**************************************************->]0.199
# [epoch 16] train_loss: 0.338 train_accuracy: 0.886 val_accuracy: 0.897  recall: 0.786  f1: 0.796
# train loss:100%[**************************************************->]0.734
# [epoch 17] train_loss: 0.309 train_accuracy: 0.894 val_accuracy: 0.892  recall: 0.765  f1: 0.774
# train loss:100%[**************************************************->]0.348
# [epoch 18] train_loss: 0.304 train_accuracy: 0.898 val_accuracy: 0.892  recall: 0.788  f1: 0.804
# train loss:100%[**************************************************->]0.220
# [epoch 19] train_loss: 0.313 train_accuracy: 0.898 val_accuracy: 0.902  recall: 0.799  f1: 0.817
# train loss:100%[**************************************************->]0.178
# [epoch 20] train_loss: 0.298 train_accuracy: 0.902 val_accuracy: 0.908  recall: 0.796  f1: 0.817
# train loss:100%[**************************************************->]1.065
# [epoch 21] train_loss: 0.292 train_accuracy: 0.903 val_accuracy: 0.902  recall: 0.806  f1: 0.823
# train loss:100%[**************************************************->]0.445
# [epoch 22] train_loss: 0.293 train_accuracy: 0.904 val_accuracy: 0.916  recall: 0.798  f1: 0.804
# train loss:100%[**************************************************->]0.616
# [epoch 23] train_loss: 0.290 train_accuracy: 0.907 val_accuracy: 0.909  recall: 0.778  f1: 0.784
# train loss:100%[**************************************************->]0.520
# [epoch 24] train_loss: 0.290 train_accuracy: 0.909 val_accuracy: 0.917  recall: 0.797  f1: 0.796
# train loss:100%[**************************************************->]0.384
# [epoch 25] train_loss: 0.271 train_accuracy: 0.914 val_accuracy: 0.911  recall: 0.802  f1: 0.805
# train loss:100%[**************************************************->]0.204
# [epoch 26] train_loss: 0.290 train_accuracy: 0.909 val_accuracy: 0.912  recall: 0.805  f1: 0.828
# train loss:100%[**************************************************->]0.419
# [epoch 27] train_loss: 0.254 train_accuracy: 0.918 val_accuracy: 0.926  recall: 0.805  f1: 0.817
# train loss:100%[**************************************************->]0.086
# [epoch 28] train_loss: 0.305 train_accuracy: 0.908 val_accuracy: 0.917  recall: 0.785  f1: 0.798
# train loss:100%[**************************************************->]0.160
# [epoch 29] train_loss: 0.270 train_accuracy: 0.915 val_accuracy: 0.911  recall: 0.784  f1: 0.800
# train loss:100%[**************************************************->]0.253
# [epoch 30] train_loss: 0.277 train_accuracy: 0.914 val_accuracy: 0.919  recall: 0.815  f1: 0.839
# train loss:100%[**************************************************->]0.024
# [epoch 31] train_loss: 0.269 train_accuracy: 0.915 val_accuracy: 0.922  recall: 0.789  f1: 0.799
# train loss:100%[**************************************************->]0.080
# [epoch 32] train_loss: 0.261 train_accuracy: 0.918 val_accuracy: 0.922  recall: 0.820  f1: 0.836
# train loss:100%[**************************************************->]0.114
# [epoch 33] train_loss: 0.261 train_accuracy: 0.920 val_accuracy: 0.907  recall: 0.804  f1: 0.833
# train loss:100%[**************************************************->]0.148
# [epoch 34] train_loss: 0.260 train_accuracy: 0.921 val_accuracy: 0.932  recall: 0.829  f1: 0.853
# train loss:100%[**************************************************->]0.300
# [epoch 35] train_loss: 0.290 train_accuracy: 0.912 val_accuracy: 0.921  recall: 0.825  f1: 0.847
# train loss:100%[**************************************************->]0.579
# [epoch 36] train_loss: 0.231 train_accuracy: 0.926 val_accuracy: 0.931  recall: 0.819  f1: 0.835
# train loss:100%[**************************************************->]0.041
# [epoch 37] train_loss: 0.302 train_accuracy: 0.916 val_accuracy: 0.911  recall: 0.791  f1: 0.803
# train loss:100%[**************************************************->]0.289
# [epoch 38] train_loss: 0.306 train_accuracy: 0.912 val_accuracy: 0.918  recall: 0.792  f1: 0.803
# train loss:100%[**************************************************->]0.243
# [epoch 39] train_loss: 0.261 train_accuracy: 0.920 val_accuracy: 0.924  recall: 0.813  f1: 0.831
# train loss:100%[**************************************************->]0.242
# [epoch 40] train_loss: 0.403 train_accuracy: 0.892 val_accuracy: 0.895  recall: 0.766  f1: 0.785
# train loss:100%[**************************************************->]0.159
# [epoch 41] train_loss: 0.253 train_accuracy: 0.921 val_accuracy: 0.927  recall: 0.798  f1: 0.805
# train loss:100%[**************************************************->]0.049
# [epoch 42] train_loss: 0.285 train_accuracy: 0.918 val_accuracy: 0.919  recall: 0.798  f1: 0.810
# train loss:100%[**************************************************->]0.234
# [epoch 43] train_loss: 0.318 train_accuracy: 0.911 val_accuracy: 0.929  recall: 0.828  f1: 0.850
# train loss:100%[**************************************************->]0.120
# [epoch 44] train_loss: 0.274 train_accuracy: 0.919 val_accuracy: 0.925  recall: 0.798  f1: 0.811
# train loss:100%[**************************************************->]0.356
# [epoch 45] train_loss: 0.286 train_accuracy: 0.919 val_accuracy: 0.882  recall: 0.736  f1: 0.749
# train loss:100%[**************************************************->]0.301
# [epoch 46] train_loss: 0.299 train_accuracy: 0.913 val_accuracy: 0.903  recall: 0.779  f1: 0.790
# train loss:100%[**************************************************->]0.307
# [epoch 47] train_loss: 0.252 train_accuracy: 0.925 val_accuracy: 0.905  recall: 0.788  f1: 0.816
# train loss:100%[**************************************************->]0.711
# [epoch 48] train_loss: 0.362 train_accuracy: 0.904 val_accuracy: 0.867  recall: 0.726  f1: 0.750
# train loss:100%[**************************************************->]0.445
# [epoch 49] train_loss: 0.265 train_accuracy: 0.918 val_accuracy: 0.924  recall: 0.798  f1: 0.805
# train loss:100%[**************************************************->]0.313
# [epoch 50] train_loss: 0.240 train_accuracy: 0.928 val_accuracy: 0.915  recall: 0.794  f1: 0.809
# train loss:100%[**************************************************->]0.4510
# [epoch 51] train_loss: 0.426 train_accuracy: 0.904 val_accuracy: 0.927  recall: 0.822  f1: 0.841
# train loss:100%[**************************************************->]0.871
# [epoch 52] train_loss: 0.319 train_accuracy: 0.909 val_accuracy: 0.901  recall: 0.772  f1: 0.778
# train loss:100%[**************************************************->]0.038
# [epoch 53] train_loss: 0.305 train_accuracy: 0.916 val_accuracy: 0.911  recall: 0.793  f1: 0.804
# train loss:100%[**************************************************->]0.055
# [epoch 54] train_loss: 0.322 train_accuracy: 0.912 val_accuracy: 0.924  recall: 0.799  f1: 0.814
# train loss:100%[**************************************************->]0.139
# [epoch 55] train_loss: 0.358 train_accuracy: 0.909 val_accuracy: 0.924  recall: 0.788  f1: 0.798
# train loss:100%[**************************************************->]0.172
# [epoch 56] train_loss: 0.281 train_accuracy: 0.921 val_accuracy: 0.926  recall: 0.802  f1: 0.809
# train loss:100%[**************************************************->]0.539
# [epoch 57] train_loss: 0.268 train_accuracy: 0.923 val_accuracy: 0.886  recall: 0.738  f1: 0.750
# train loss:100%[**************************************************->]0.734
# [epoch 58] train_loss: 0.272 train_accuracy: 0.922 val_accuracy: 0.928  recall: 0.797  f1: 0.805
# train loss:100%[**************************************************->]0.062
# [epoch 59] train_loss: 0.311 train_accuracy: 0.917 val_accuracy: 0.903  recall: 0.766  f1: 0.773
# train loss:100%[**************************************************->]0.0177
# [epoch 60] train_loss: 0.495 train_accuracy: 0.908 val_accuracy: 0.913  recall: 0.780  f1: 0.790
# train loss:100%[**************************************************->]0.450
# [epoch 61] train_loss: 0.266 train_accuracy: 0.925 val_accuracy: 0.928  recall: 0.800  f1: 0.810
# train loss:100%[**************************************************->]0.088
# [epoch 62] train_loss: 0.483 train_accuracy: 0.885 val_accuracy: 0.907  recall: 0.743  f1: 0.756
# train loss:100%[**************************************************->]0.530
# [epoch 63] train_loss: 0.331 train_accuracy: 0.911 val_accuracy: 0.926  recall: 0.783  f1: 0.786
# train loss:100%[**************************************************->]0.312
# [epoch 64] train_loss: 0.425 train_accuracy: 0.894 val_accuracy: 0.925  recall: 0.776  f1: 0.783
# train loss:100%[**************************************************->]0.078
# [epoch 65] train_loss: 0.290 train_accuracy: 0.922 val_accuracy: 0.908  recall: 0.752  f1: 0.750
# train loss:100%[**************************************************->]0.499
# [epoch 66] train_loss: 0.329 train_accuracy: 0.909 val_accuracy: 0.901  recall: 0.734  f1: 0.746
# train loss:100%[**************************************************->]0.609
# [epoch 67] train_loss: 0.313 train_accuracy: 0.913 val_accuracy: 0.903  recall: 0.756  f1: 0.755
# train loss:100%[**************************************************->]0.117
# [epoch 68] train_loss: 0.281 train_accuracy: 0.919 val_accuracy: 0.921  recall: 0.786  f1: 0.793
# train loss:100%[**************************************************->]2.351
# [epoch 69] train_loss: 0.517 train_accuracy: 0.872 val_accuracy: 0.886  recall: 0.732  f1: 0.731
# train loss:100%[**************************************************->]0.116
# [epoch 70] train_loss: 0.308 train_accuracy: 0.913 val_accuracy: 0.923  recall: 0.784  f1: 0.789
# train loss:100%[**************************************************->]0.413
# [epoch 71] train_loss: 0.394 train_accuracy: 0.905 val_accuracy: 0.893  recall: 0.728  f1: 0.731
# train loss:100%[**************************************************->]0.525
# [epoch 72] train_loss: 0.443 train_accuracy: 0.889 val_accuracy: 0.877  recall: 0.716  f1: 0.737
# train loss:100%[**************************************************->]0.143
# [epoch 73] train_loss: 0.343 train_accuracy: 0.908 val_accuracy: 0.920  recall: 0.768  f1: 0.781
# train loss:100%[**************************************************->]0.660
# [epoch 74] train_loss: 0.376 train_accuracy: 0.901 val_accuracy: 0.860  recall: 0.696  f1: 0.719
# train loss:100%[**************************************************->]0.456
# [epoch 75] train_loss: 0.438 train_accuracy: 0.892 val_accuracy: 0.916  recall: 0.765  f1: 0.788
# train loss:100%[**************************************************->]0.594
# [epoch 76] train_loss: 0.364 train_accuracy: 0.910 val_accuracy: 0.883  recall: 0.700  f1: 0.719
# train loss:100%[**************************************************->]0.438
# [epoch 77] train_loss: 0.376 train_accuracy: 0.907 val_accuracy: 0.864  recall: 0.708  f1: 0.736
# train loss:100%[**************************************************->]0.192
# [epoch 78] train_loss: 0.388 train_accuracy: 0.900 val_accuracy: 0.926  recall: 0.776  f1: 0.784
# train loss:100%[**************************************************->]0.147
# [epoch 79] train_loss: 0.350 train_accuracy: 0.906 val_accuracy: 0.923  recall: 0.766  f1: 0.777
# train loss:100%[**************************************************->]0.527
# [epoch 80] train_loss: 0.471 train_accuracy: 0.888 val_accuracy: 0.898  recall: 0.721  f1: 0.730
# train loss:100%[**************************************************->]0.061
# [epoch 81] train_loss: 0.343 train_accuracy: 0.906 val_accuracy: 0.912  recall: 0.747  f1: 0.769
# train loss:100%[**************************************************->]0.4404
# [epoch 82] train_loss: 1.059 train_accuracy: 0.754 val_accuracy: 0.837  recall: 0.646  f1: 0.684
# train loss:100%[**************************************************->]0.47228
# [epoch 83] train_loss: 1.208 train_accuracy: 0.815 val_accuracy: 0.827  recall: 0.598  f1: 0.618
# train loss:100%[**************************************************->]0.112
# [epoch 84] train_loss: 0.508 train_accuracy: 0.860 val_accuracy: 0.892  recall: 0.705  f1: 0.733
# train loss:100%[**************************************************->]0.438
# [epoch 85] train_loss: 0.478 train_accuracy: 0.877 val_accuracy: 0.870  recall: 0.662  f1: 0.678
# train loss:100%[**************************************************->]0.406
# [epoch 86] train_loss: 0.518 train_accuracy: 0.874 val_accuracy: 0.897  recall: 0.696  f1: 0.724
# train loss:100%[**************************************************->]0.3469
# [epoch 87] train_loss: 0.611 train_accuracy: 0.869 val_accuracy: 0.858  recall: 0.658  f1: 0.698
# train loss:100%[**************************************************->]0.536
# [epoch 88] train_loss: 0.637 train_accuracy: 0.854 val_accuracy: 0.877  recall: 0.670  f1: 0.698
# train loss:100%[**************************************************->]0.545
# [epoch 89] train_loss: 0.516 train_accuracy: 0.867 val_accuracy: 0.886  recall: 0.709  f1: 0.739
# train loss:100%[**************************************************->]0.212
# [epoch 90] train_loss: 0.492 train_accuracy: 0.876 val_accuracy: 0.896  recall: 0.710  f1: 0.736
# train loss:100%[**************************************************->]0.4388
# [epoch 91] train_loss: 0.690 train_accuracy: 0.849 val_accuracy: 0.884  recall: 0.680  f1: 0.701
# train loss:100%[**************************************************->]0.80866
# [epoch 92] train_loss: 0.980 train_accuracy: 0.866 val_accuracy: 0.834  recall: 0.624  f1: 0.661
# train loss:100%[**************************************************->]0.670
# [epoch 93] train_loss: 0.667 train_accuracy: 0.839 val_accuracy: 0.866  recall: 0.643  f1: 0.661
# train loss:100%[**************************************************->]0.993
# [epoch 94] train_loss: 0.564 train_accuracy: 0.861 val_accuracy: 0.887  recall: 0.687  f1: 0.707
# train loss:100%[**************************************************->]0.486
# [epoch 95] train_loss: 0.693 train_accuracy: 0.843 val_accuracy: 0.852  recall: 0.597  f1: 0.611
# train loss:100%[**************************************************->]0.7175
# [epoch 96] train_loss: 0.834 train_accuracy: 0.820 val_accuracy: 0.771  recall: 0.547  f1: 0.567
# train loss:100%[**************************************************->]0.6372
# [epoch 97] train_loss: 0.683 train_accuracy: 0.831 val_accuracy: 0.779  recall: 0.512  f1: 0.548
# train loss:100%[**************************************************->]0.609
# [epoch 98] train_loss: 0.851 train_accuracy: 0.812 val_accuracy: 0.780  recall: 0.493  f1: 0.514
# train loss:100%[**************************************************->]0.299
# [epoch 99] train_loss: 0.708 train_accuracy: 0.824 val_accuracy: 0.841  recall: 0.565  f1: 0.586
# train loss:100%[**************************************************->]0.650
# [epoch 100] train_loss: 0.797 train_accuracy: 0.811 val_accuracy: 0.814  recall: 0.543  f1: 0.561
# Finished Training
