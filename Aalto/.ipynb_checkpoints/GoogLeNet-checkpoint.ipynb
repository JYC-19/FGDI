# %%
import torch.nn as nn
import torch
import torch.nn.functional as F

class GoogLeNet(nn.Module):
    def __init__(self, num_classes=40, aux_logits=True, init_weights=True):
        super(GoogLeNet,self).__init__()
        self.aux_logits = aux_logits

        self.conv1 = BasicConv1d(1, 64, kernel_size=7, stride=2, padding=3)    
        self.maxpool1 = nn.MaxPool1d(3, stride=2, ceil_mode=True)              

        self.conv2 = BasicConv1d(64, 64, kernel_size=1)
        self.conv3 = BasicConv1d(64, 192, kernel_size=3, padding=1)
        self.maxpool2 = nn.MaxPool1d(3, stride=2, ceil_mode=True)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool1d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool1d(3, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)

        if self.aux_logits:
            self.aux1 = InceptionAux(512, num_classes)
            self.aux2 = InceptionAux(528, num_classes)

        self.avgpool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, num_classes)
        if init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.maxpool2(x)

        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)
        x = self.inception4a(x)
        if self.training and self.aux_logits:  
            aux1 = self.aux1(x)

        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        if self.training and self.aux_logits: 
            aux2 = self.aux2(x)

        x = self.inception4e(x)
        x = self.maxpool4(x)
        x = self.inception5a(x)
        x = self.inception5b(x)

        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        if self.training and self.aux_logits:  
            return x, aux2, aux1
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

class Inception(nn.Module):
    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception,self).__init__()

        self.branch1 = BasicConv1d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv1d(in_channels, ch3x3red, kernel_size=1),
            BasicConv1d(ch3x3red, ch3x3, kernel_size=3, padding=1)          
        )

        self.branch3 = nn.Sequential(
            BasicConv1d(in_channels, ch5x5red, kernel_size=1),
            BasicConv1d(ch5x5red, ch5x5, kernel_size=5, padding=2)        
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool1d(kernel_size=3, stride=1, padding=1),        
            BasicConv1d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        outputs = [branch1, branch2, branch3, branch4]
        return torch.cat(outputs, 1)

class InceptionAux(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(InceptionAux,self).__init__()
        self.averagePool = nn.AvgPool1d(kernel_size=5, stride=3)
        self.conv = BasicConv1d(in_channels, 128, kernel_size=1)

        self.fc1 = nn.Linear(3840, 1024)
        self.fc2 = nn.Linear(1024,num_classes)

    def forward(self, x):
        x = self.averagePool(x)
        x = self.conv(x)
        x = torch.flatten(x, 1)

        x = F.dropout(x, 0.5, training=self.training)
        x = F.relu(self.fc1(x), inplace=True)
        x = F.dropout(x, 0.5, training=self.training)
        x = self.fc2(x)
        return x

class BasicConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv1d, self).__init__()
        self.conv = nn.Conv1d(in_channels, out_channels, **kwargs)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.relu(x)
        return x

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np

def plot_matrix(conf_matrix, dev_list, save_path):
    plt.figure(figsize=(20, 16), dpi=300)
    plt.imshow(conf_matrix, cmap=plt.cm.Blues, interpolation='nearest')
    plt.title('Confusion Matrix')
    plt.colorbar()

    thresh = conf_matrix.max() / 2.
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            plt.text(j, i, conf_matrix[i, j],
                     ha="center", va="center",
                     color="white" if conf_matrix[i, j] > thresh else "black", fontsize=8)

    tick_marks = np.arange(len(dev_list))
    plt.xticks(tick_marks, dev_list, fontsize=8)
    plt.yticks(tick_marks, dev_list, fontsize=8)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

    plt.gca().set_aspect(aspect='equal')

    plt.savefig(save_path)
    plt.show()

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
import numpy as np
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.categories = sorted(os.listdir(data_dir))
        self.data = []
        self.transform = transform
        for category in self.categories:
            category_dir = os.path.join(data_dir, category)
            category_data = sorted(os.listdir(category_dir))
            self.data.extend([(os.path.join(category_dir, file), self.categories.index(category)) for file in category_data])

    def __getitem__(self, index):
        file_path, label = self.data[index]
        data = np.load(file_path)
        image = Image.fromarray(data.astype(np.uint8))
        image = transform(image)
        return image, label

    def __len__(self):
        return len(self.data)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("using {} device.".format(device))

transform = transforms.Compose([ transforms.Grayscale(num_output_channels = 1),
                                     transforms.ToTensor(),
                                     transforms.Normalize((0.5), (0.5))])

train_dataset = CustomDataset("features/train_npy",transform=transform)
train_num = len(train_dataset)
dev_list = train_dataset.categories

batch_size = 32
train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=batch_size, shuffle=True,
                                               num_workers=0)

validate_dataset = CustomDataset("features/val_npy",transform=transform)
val_num = len(validate_dataset)
validate_loader = torch.utils.data.DataLoader(validate_dataset,
                                                  batch_size=batch_size, shuffle=False,
                                                  num_workers=0)

print("using {} images for training, {} images for validation.".format(train_num, val_num))

net = GoogLeNet(num_classes=31, aux_logits=True, init_weights=True)
net.to(device)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

epochs = 100
save_path = './GoogLeNet_parameters.pth'
best_f1 = 0.0
train_accurate_list = []
val_accurate_list = []
f1_list = []
recall_list = []

for epoch in range(epochs):
    net.train()
    running_loss = 0.0
    train_acc = 0.0
    for step, data in enumerate(train_loader, start=0):
        images, labels = data
        images = images.reshape(images.shape[0], 1, 1503)
        optimizer.zero_grad()
        logits, aux_logits2, aux_logits1 = net(images.to(device))
        predict_y = torch.max(logits, dim=1)[1]
        train_acc += torch.eq(predict_y, labels.to(device)).sum().item()
        loss0 = loss_function(logits, labels.to(device))
        loss1 = loss_function(aux_logits1, labels.to(device))
        loss2 = loss_function(aux_logits2, labels.to(device))
        loss = loss0 + loss1 * 0.3 + loss2 * 0.3
        loss.backward()
        optimizer.step()

      
        running_loss += loss.item()
        rate = (step + 1) / len(train_loader)
        a = "*" * int(rate * 50)
        b = "." * int((1 - rate) * 50)
        print("\rtrain loss:{:^3.0f}%[{}->{}]{:.3f}".format(int(rate * 100), a, b, loss), end="")
    print()
    train_accurate = train_acc / train_num
    train_accurate_list.append(train_accurate)
    # validate
    net.eval()
    acc = 0.0 
    val = torch.tensor([])
    pre = torch.tensor([])
    with torch.no_grad():
        for val_data in validate_loader:
            val_images, val_labels = val_data
            val_images = val_images.reshape(val_images.shape[0], 1, 1503)
            outputs = net(val_images.to(device))
            predict_y = torch.max(outputs, dim=1)[1]
            pre = torch.cat([pre.to(device), predict_y.to(device)])
            val = torch.cat([val.to(device), val_labels.to(device)])
            acc += torch.eq(predict_y, val_labels.to(device)).sum().item()
    val_accurate = acc / val_num
    val_accurate_list.append(val_accurate)
    f1 = f1_score(val.cpu(), pre.cpu(), average='macro')
    recall = recall_score(val.cpu(), pre.cpu(), average='macro')

    f1_list.append(f1)
    recall_list.append(recall)
    if f1 > best_f1:
        best_f1 = f1
        best_pre = pre
        best_val = val
        torch.save(net.state_dict(), save_path)
        torch.save(best_pre, 'pre_val_label/best_pre_GoogLeNet.pt')
        torch.save(best_val, 'pre_val_label/best_val_GoogLeNet.pt')
    print('[epoch %d] train_loss: %.3f train_accuracy: %.3f val_accuracy: %.3f  recall: %.3f  f1: %.3f' %
              (epoch + 1, running_loss / step, train_accurate, val_accurate, recall, f1))
    with open("GoogLeNet_result_npy.txt", 'a') as file:
        file.write("[epoch " + str(epoch + 1) + "]" + "  " + "train_accuracy:" + str(train_accurate) + "  " + "val_accuracy:" + str(val_accurate) + "  " + "recall:" + str(recall) + "  " + "f1:" + str(f1) + '\n')
print('Finished Training')

iterations = range(1, len(train_accurate_list) + 1)
with open("GoogLeNet_npy_plt_data.txt", 'a') as file:
    file.write("iterations:" + str(iterations) +
               "train_accurate_list:" + str(train_accurate_list) +
               "val_accurate_list:" + str(val_accurate_list) +
               "f1_list:" + str(f1_list) +
               "recall_list:" + str(recall_list) +
               "dev_list:" + str(dev_list) + '\n')
conf_matrix = confusion_matrix(best_val.cpu(),best_pre.cpu())
plot_matrix(conf_matrix,dev_list,"GoogLeNet_confusion_matrix_npy.png")
# Out:
# using cuda:0 device.
# using 82841 images for training, 20695 images for validation.
# train loss:100%[**************************************************->]1.931
# [epoch 1] train_loss: 2.691 train_accuracy: 0.443 val_accuracy: 0.620  recall: 0.368  f1: 0.337
# train loss:100%[**************************************************->]1.221
# [epoch 2] train_loss: 1.426 train_accuracy: 0.658 val_accuracy: 0.694  recall: 0.516  f1: 0.495
# train loss:100%[**************************************************->]1.284
# [epoch 3] train_loss: 1.173 train_accuracy: 0.708 val_accuracy: 0.738  recall: 0.585  f1: 0.585
# train loss:100%[**************************************************->]1.176
# [epoch 4] train_loss: 1.049 train_accuracy: 0.739 val_accuracy: 0.765  recall: 0.623  f1: 0.617
# train loss:100%[**************************************************->]0.524
# [epoch 5] train_loss: 0.930 train_accuracy: 0.769 val_accuracy: 0.794  recall: 0.648  f1: 0.654
# train loss:100%[**************************************************->]1.099
# [epoch 6] train_loss: 0.849 train_accuracy: 0.792 val_accuracy: 0.791  recall: 0.647  f1: 0.652
# train loss:100%[**************************************************->]1.079
# [epoch 7] train_loss: 0.778 train_accuracy: 0.812 val_accuracy: 0.824  recall: 0.693  f1: 0.703
# train loss:100%[**************************************************->]0.569
# [epoch 8] train_loss: 0.708 train_accuracy: 0.833 val_accuracy: 0.840  recall: 0.709  f1: 0.712
# train loss:100%[**************************************************->]0.574
# [epoch 9] train_loss: 0.652 train_accuracy: 0.848 val_accuracy: 0.862  recall: 0.733  f1: 0.732
# train loss:100%[**************************************************->]0.656
# [epoch 10] train_loss: 0.601 train_accuracy: 0.863 val_accuracy: 0.849  recall: 0.690  f1: 0.705
# train loss:100%[**************************************************->]0.366
# [epoch 11] train_loss: 0.543 train_accuracy: 0.879 val_accuracy: 0.877  recall: 0.756  f1: 0.770
# train loss:100%[**************************************************->]0.461
# [epoch 12] train_loss: 0.511 train_accuracy: 0.887 val_accuracy: 0.879  recall: 0.751  f1: 0.751
# train loss:100%[**************************************************->]0.857
# [epoch 13] train_loss: 0.492 train_accuracy: 0.892 val_accuracy: 0.875  recall: 0.725  f1: 0.739
# train loss:100%[**************************************************->]0.287
# [epoch 14] train_loss: 0.459 train_accuracy: 0.901 val_accuracy: 0.905  recall: 0.790  f1: 0.798
# train loss:100%[**************************************************->]0.182
# [epoch 15] train_loss: 0.429 train_accuracy: 0.909 val_accuracy: 0.906  recall: 0.783  f1: 0.785
# train loss:100%[**************************************************->]0.284
# [epoch 16] train_loss: 0.436 train_accuracy: 0.910 val_accuracy: 0.905  recall: 0.789  f1: 0.790
# train loss:100%[**************************************************->]0.607
# [epoch 17] train_loss: 0.381 train_accuracy: 0.922 val_accuracy: 0.908  recall: 0.802  f1: 0.817
# train loss:100%[**************************************************->]0.413
# [epoch 18] train_loss: 0.387 train_accuracy: 0.921 val_accuracy: 0.916  recall: 0.793  f1: 0.798
# train loss:100%[**************************************************->]0.441
# [epoch 19] train_loss: 0.383 train_accuracy: 0.924 val_accuracy: 0.915  recall: 0.823  f1: 0.842
# train loss:100%[**************************************************->]0.529
# [epoch 20] train_loss: 0.346 train_accuracy: 0.931 val_accuracy: 0.924  recall: 0.801  f1: 0.810
# train loss:100%[**************************************************->]0.177
# [epoch 21] train_loss: 0.372 train_accuracy: 0.928 val_accuracy: 0.929  recall: 0.841  f1: 0.858
# train loss:100%[**************************************************->]0.234
# [epoch 22] train_loss: 0.354 train_accuracy: 0.931 val_accuracy: 0.934  recall: 0.835  f1: 0.849
# train loss:100%[**************************************************->]0.314
# [epoch 23] train_loss: 0.333 train_accuracy: 0.935 val_accuracy: 0.934  recall: 0.834  f1: 0.849
# train loss:100%[**************************************************->]0.445
# [epoch 24] train_loss: 0.331 train_accuracy: 0.936 val_accuracy: 0.935  recall: 0.824  f1: 0.836
# train loss:100%[**************************************************->]0.213
# [epoch 25] train_loss: 0.325 train_accuracy: 0.937 val_accuracy: 0.919  recall: 0.827  f1: 0.845
# train loss:100%[**************************************************->]0.153
# [epoch 26] train_loss: 0.328 train_accuracy: 0.939 val_accuracy: 0.928  recall: 0.813  f1: 0.824
# train loss:100%[**************************************************->]0.184
# [epoch 27] train_loss: 0.302 train_accuracy: 0.942 val_accuracy: 0.920  recall: 0.827  f1: 0.847
# train loss:100%[**************************************************->]0.039
# [epoch 28] train_loss: 0.320 train_accuracy: 0.939 val_accuracy: 0.941  recall: 0.842  f1: 0.859
# train loss:100%[**************************************************->]0.366
# [epoch 29] train_loss: 0.314 train_accuracy: 0.942 val_accuracy: 0.923  recall: 0.837  f1: 0.841
# train loss:100%[**************************************************->]0.710
# [epoch 30] train_loss: 0.309 train_accuracy: 0.944 val_accuracy: 0.937  recall: 0.839  f1: 0.852
# train loss:100%[**************************************************->]0.315
# [epoch 31] train_loss: 0.297 train_accuracy: 0.946 val_accuracy: 0.939  recall: 0.851  f1: 0.862
# train loss:100%[**************************************************->]0.131
# [epoch 32] train_loss: 0.460 train_accuracy: 0.922 val_accuracy: 0.943  recall: 0.841  f1: 0.861
# train loss:100%[**************************************************->]0.465
# [epoch 33] train_loss: 0.271 train_accuracy: 0.949 val_accuracy: 0.931  recall: 0.823  f1: 0.842
# train loss:100%[**************************************************->]0.087
# [epoch 34] train_loss: 0.334 train_accuracy: 0.941 val_accuracy: 0.932  recall: 0.833  f1: 0.852
# train loss:100%[**************************************************->]0.092
# [epoch 35] train_loss: 0.290 train_accuracy: 0.947 val_accuracy: 0.948  recall: 0.851  f1: 0.863
# train loss:100%[**************************************************->]0.431
# [epoch 36] train_loss: 0.284 train_accuracy: 0.949 val_accuracy: 0.942  recall: 0.833  f1: 0.844
# train loss:100%[**************************************************->]0.215
# [epoch 37] train_loss: 0.338 train_accuracy: 0.943 val_accuracy: 0.948  recall: 0.833  f1: 0.846
# train loss:100%[**************************************************->]0.983
# [epoch 38] train_loss: 0.277 train_accuracy: 0.951 val_accuracy: 0.939  recall: 0.847  f1: 0.852
# train loss:100%[**************************************************->]0.235
# [epoch 39] train_loss: 0.264 train_accuracy: 0.952 val_accuracy: 0.947  recall: 0.854  f1: 0.872
# train loss:100%[**************************************************->]0.172
# [epoch 40] train_loss: 0.283 train_accuracy: 0.951 val_accuracy: 0.942  recall: 0.842  f1: 0.860
# train loss:100%[**************************************************->]0.200
# [epoch 41] train_loss: 0.313 train_accuracy: 0.947 val_accuracy: 0.948  recall: 0.851  f1: 0.869
# train loss:100%[**************************************************->]0.255
# [epoch 42] train_loss: 0.265 train_accuracy: 0.954 val_accuracy: 0.946  recall: 0.846  f1: 0.864
# train loss:100%[**************************************************->]0.321
# [epoch 43] train_loss: 0.299 train_accuracy: 0.950 val_accuracy: 0.910  recall: 0.774  f1: 0.787
# train loss:100%[**************************************************->]0.400
# [epoch 44] train_loss: 0.336 train_accuracy: 0.945 val_accuracy: 0.946  recall: 0.854  f1: 0.867
# train loss:100%[**************************************************->]0.063
# [epoch 45] train_loss: 0.309 train_accuracy: 0.949 val_accuracy: 0.947  recall: 0.849  f1: 0.864
# train loss:100%[**************************************************->]0.447
# [epoch 46] train_loss: 0.269 train_accuracy: 0.952 val_accuracy: 0.947  recall: 0.857  f1: 0.871
# train loss:100%[**************************************************->]0.105
# [epoch 47] train_loss: 0.341 train_accuracy: 0.946 val_accuracy: 0.950  recall: 0.854  f1: 0.871
# train loss:100%[**************************************************->]0.640
# [epoch 48] train_loss: 0.285 train_accuracy: 0.952 val_accuracy: 0.949  recall: 0.852  f1: 0.871
# train loss:100%[**************************************************->]0.074
# [epoch 49] train_loss: 0.283 train_accuracy: 0.954 val_accuracy: 0.940  recall: 0.836  f1: 0.843
# train loss:100%[**************************************************->]0.140
# [epoch 50] train_loss: 0.306 train_accuracy: 0.949 val_accuracy: 0.951  recall: 0.857  f1: 0.871
# train loss:100%[**************************************************->]0.197
# [epoch 51] train_loss: 0.266 train_accuracy: 0.955 val_accuracy: 0.941  recall: 0.843  f1: 0.860
# train loss:100%[**************************************************->]0.437
# [epoch 52] train_loss: 0.261 train_accuracy: 0.956 val_accuracy: 0.907  recall: 0.801  f1: 0.811
# train loss:100%[**************************************************->]0.164
# [epoch 53] train_loss: 0.307 train_accuracy: 0.949 val_accuracy: 0.949  recall: 0.858  f1: 0.875
# train loss:100%[**************************************************->]0.521
# [epoch 54] train_loss: 0.258 train_accuracy: 0.957 val_accuracy: 0.954  recall: 0.856  f1: 0.866
# train loss:100%[**************************************************->]0.525
# [epoch 55] train_loss: 0.286 train_accuracy: 0.953 val_accuracy: 0.953  recall: 0.853  f1: 0.867
# train loss:100%[**************************************************->]0.106
# [epoch 56] train_loss: 0.296 train_accuracy: 0.951 val_accuracy: 0.947  recall: 0.838  f1: 0.847
# train loss:100%[**************************************************->]0.463
# [epoch 57] train_loss: 0.269 train_accuracy: 0.955 val_accuracy: 0.946  recall: 0.847  f1: 0.866
# train loss:100%[**************************************************->]0.247
# [epoch 58] train_loss: 0.283 train_accuracy: 0.954 val_accuracy: 0.957  recall: 0.863  f1: 0.883
# train loss:100%[**************************************************->]0.178
# [epoch 59] train_loss: 0.332 train_accuracy: 0.948 val_accuracy: 0.940  recall: 0.838  f1: 0.845
# train loss:100%[**************************************************->]0.340
# [epoch 60] train_loss: 0.285 train_accuracy: 0.956 val_accuracy: 0.899  recall: 0.787  f1: 0.796
# train loss:100%[**************************************************->]0.477
# [epoch 61] train_loss: 0.285 train_accuracy: 0.953 val_accuracy: 0.951  recall: 0.854  f1: 0.869
# train loss:100%[**************************************************->]0.170
# [epoch 62] train_loss: 0.279 train_accuracy: 0.955 val_accuracy: 0.952  recall: 0.858  f1: 0.867
# train loss:100%[**************************************************->]0.244
# [epoch 63] train_loss: 0.308 train_accuracy: 0.952 val_accuracy: 0.946  recall: 0.844  f1: 0.860
# train loss:100%[**************************************************->]0.313
# [epoch 64] train_loss: 0.307 train_accuracy: 0.951 val_accuracy: 0.938  recall: 0.815  f1: 0.841
# train loss:100%[**************************************************->]0.047
# [epoch 65] train_loss: 0.274 train_accuracy: 0.957 val_accuracy: 0.950  recall: 0.856  f1: 0.864
# train loss:100%[**************************************************->]0.297
# [epoch 66] train_loss: 0.276 train_accuracy: 0.954 val_accuracy: 0.950  recall: 0.856  f1: 0.870
# train loss:100%[**************************************************->]0.360
# [epoch 67] train_loss: 0.335 train_accuracy: 0.950 val_accuracy: 0.910  recall: 0.755  f1: 0.765
# train loss:100%[**************************************************->]0.665
# [epoch 68] train_loss: 0.315 train_accuracy: 0.952 val_accuracy: 0.930  recall: 0.811  f1: 0.819
# train loss:100%[**************************************************->]0.865
# [epoch 69] train_loss: 0.316 train_accuracy: 0.952 val_accuracy: 0.950  recall: 0.851  f1: 0.867
# train loss:100%[**************************************************->]0.110
# [epoch 70] train_loss: 0.281 train_accuracy: 0.956 val_accuracy: 0.953  recall: 0.857  f1: 0.869
# train loss:100%[**************************************************->]0.437
# [epoch 71] train_loss: 0.315 train_accuracy: 0.952 val_accuracy: 0.955  recall: 0.859  f1: 0.871
# train loss:100%[**************************************************->]0.295
# [epoch 72] train_loss: 0.342 train_accuracy: 0.950 val_accuracy: 0.953  recall: 0.855  f1: 0.872
# train loss:100%[**************************************************->]0.046
# [epoch 73] train_loss: 0.293 train_accuracy: 0.956 val_accuracy: 0.946  recall: 0.850  f1: 0.862
# train loss:100%[**************************************************->]0.247
# [epoch 74] train_loss: 0.263 train_accuracy: 0.957 val_accuracy: 0.950  recall: 0.856  f1: 0.866
# train loss:100%[**************************************************->]0.216
# [epoch 75] train_loss: 0.364 train_accuracy: 0.947 val_accuracy: 0.955  recall: 0.862  f1: 0.875
# train loss:100%[**************************************************->]0.006
# [epoch 76] train_loss: 0.269 train_accuracy: 0.958 val_accuracy: 0.938  recall: 0.829  f1: 0.848
# train loss:100%[**************************************************->]0.076
# [epoch 77] train_loss: 0.326 train_accuracy: 0.950 val_accuracy: 0.954  recall: 0.853  f1: 0.869
# train loss:100%[**************************************************->]0.260
# [epoch 78] train_loss: 0.340 train_accuracy: 0.950 val_accuracy: 0.941  recall: 0.832  f1: 0.846
# train loss:100%[**************************************************->]0.337
# [epoch 79] train_loss: 0.254 train_accuracy: 0.960 val_accuracy: 0.934  recall: 0.828  f1: 0.846
# train loss:100%[**************************************************->]0.132
# [epoch 80] train_loss: 0.297 train_accuracy: 0.954 val_accuracy: 0.926  recall: 0.824  f1: 0.841
# train loss:100%[**************************************************->]0.750
# [epoch 81] train_loss: 0.264 train_accuracy: 0.959 val_accuracy: 0.909  recall: 0.822  f1: 0.832
# train loss:100%[**************************************************->]0.480
# [epoch 82] train_loss: 0.329 train_accuracy: 0.950 val_accuracy: 0.953  recall: 0.857  f1: 0.871
# train loss:100%[**************************************************->]0.373
# [epoch 83] train_loss: 0.373 train_accuracy: 0.946 val_accuracy: 0.953  recall: 0.854  f1: 0.869
# train loss:100%[**************************************************->]0.287
# [epoch 84] train_loss: 0.301 train_accuracy: 0.957 val_accuracy: 0.956  recall: 0.858  f1: 0.876
# train loss:100%[**************************************************->]0.064
# [epoch 85] train_loss: 0.314 train_accuracy: 0.953 val_accuracy: 0.954  recall: 0.860  f1: 0.880
# train loss:100%[**************************************************->]0.255
# [epoch 86] train_loss: 0.308 train_accuracy: 0.953 val_accuracy: 0.946  recall: 0.842  f1: 0.856
# train loss:100%[**************************************************->]0.183
# [epoch 87] train_loss: 0.382 train_accuracy: 0.943 val_accuracy: 0.941  recall: 0.846  f1: 0.855
# train loss:100%[**************************************************->]0.350
# [epoch 88] train_loss: 0.308 train_accuracy: 0.955 val_accuracy: 0.953  recall: 0.858  f1: 0.869
# train loss:100%[**************************************************->]0.175
# [epoch 89] train_loss: 0.285 train_accuracy: 0.957 val_accuracy: 0.934  recall: 0.825  f1: 0.848
# train loss:100%[**************************************************->]0.663
# [epoch 90] train_loss: 0.293 train_accuracy: 0.956 val_accuracy: 0.954  recall: 0.859  f1: 0.874
# train loss:100%[**************************************************->]0.221
# [epoch 91] train_loss: 0.315 train_accuracy: 0.953 val_accuracy: 0.944  recall: 0.845  f1: 0.866
# train loss:100%[**************************************************->]0.003
# [epoch 92] train_loss: 0.285 train_accuracy: 0.957 val_accuracy: 0.957  recall: 0.853  f1: 0.873
# train loss:100%[**************************************************->]0.230
# [epoch 93] train_loss: 0.325 train_accuracy: 0.953 val_accuracy: 0.949  recall: 0.855  f1: 0.865
# train loss:100%[**************************************************->]1.391
# [epoch 94] train_loss: 0.305 train_accuracy: 0.955 val_accuracy: 0.957  recall: 0.858  f1: 0.878
# train loss:100%[**************************************************->]0.1352
# [epoch 95] train_loss: 0.483 train_accuracy: 0.945 val_accuracy: 0.944  recall: 0.851  f1: 0.873
# train loss:100%[**************************************************->]0.001
# [epoch 96] train_loss: 0.252 train_accuracy: 0.961 val_accuracy: 0.954  recall: 0.834  f1: 0.845
# train loss:100%[**************************************************->]0.2617
# [epoch 97] train_loss: 0.385 train_accuracy: 0.951 val_accuracy: 0.947  recall: 0.851  f1: 0.865
# train loss:100%[**************************************************->]0.369
# [epoch 98] train_loss: 0.276 train_accuracy: 0.958 val_accuracy: 0.952  recall: 0.856  f1: 0.870
# train loss:100%[**************************************************->]0.251
# [epoch 99] train_loss: 0.315 train_accuracy: 0.954 val_accuracy: 0.945  recall: 0.851  f1: 0.867
# train loss:100%[**************************************************->]0.099
# [epoch 100] train_loss: 0.329 train_accuracy: 0.953 val_accuracy: 0.946  recall: 0.842  f1: 0.854
# Finished Training
