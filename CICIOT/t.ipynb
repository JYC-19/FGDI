# %%
import os
def create_folders(folder_names):
    for folder_name in folder_names:
        folder_path = "features/val_npy/" + folder_name
        try:
            os.mkdir(folder_path)
            print("文件夹" + folder_name + "创建成功")
        except FileExistsError:
            print("文件夹" + folder_name + "已经创建")

dev_name = ['Amazon Alexa Echo Dot 1', 'Amazon Alexa Echo Dot 2', 'Amazon Alexa Echo Spot', 'Amazon Alexa Echo Studio', 'Google Nest Mini', 'Sonos One Speaker', 'AMCREST WiFi Camera', 'Arlo Base Station', 'Arlo Q Camera', 'Borun Sichuan-AI Camera', 'DCS8000LHA1 D-Link Mini Camera', 'HeimVision Smart WiFi Camera', 'Home Eye Camera', 'Luohe Cam Dog', 'Nest Indoor Camera', 'Netatmo Camera', 'SIMCAM 1S (AMPAKTec)', 'Amazon Plug', 'Atomi Coffee Maker', 'Eufy HomeBase 2', 'Globe Lamp ESP B1680C', 'Gosund ESP 039AAF Socket', 'Gosund ESP 032979 Plug', 'Gosund ESP 10098F Socket', 'Gosund ESP 0C3994 Plug', 'Gosund ESP 1ACEE1  Socket', 'Gosund ESP 147FF9 Plug', 'Gosund ESP 10ACD8 Plug', 'HeimVision SmartLife Radio Lamp', 'Philips Hue Bridge', 'Ring Base Station AC 1236', 'iRobot Roomba', 'Smart Board', 'Teckin Plug 1', 'Teckin Plug 2', 'Yutron Plug 1', 'Yutron Plug 2', 'D-Link DCHS-161 Water Sensor', 'LG Smart TV', 'Netatmo Weather Station']
create_folders(dev_name)

# def get_file_name_1(file_path):
#     file_names = os.listdir(file_path)
#     return file_names
#
# file_path = 'split_data'
# file_names = get_file_name_1(file_path)

# import os
# def count_files_in_folder(folder_path):
#     count = 0
#     for root, dirs, files in os.walk(folder_path):
#         count += len(files)
#     return count
#
# def count_files_in_subfolders(root_folder_path):
#     result = {}
#     for root, dirs, files in os.walk(root_folder_path):
#         num_files = count_files_in_folder(root)
#         result[root] = num_files
#     return result
#
# folder_path = "features/figure"
# subfolders_file_count = count_files_in_subfolders(folder_path)
#
# for folder, count in subfolders_file_count.items():
#     print("Folder:", folder)
#     print("Number of files:", count)
#     print("------------------")

# import numpy as np
# arr = np.random.random((2, 2))
# print(arr)
# np.save('array.npy', arr)
# arr = np.load('array.npy')

# import numpy as np
# i = 0
# arr = [1, 2, 3]
# arr = np.array(arr)
# arr = np.insert(arr, 0, i)
# print(arr.shape)



# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.ticker import ScalarFormatter
# arr = np.load("pck_lengths.npy")
# # 计算每个区间内数据包的数量
# bin_edges = np.arange(0, max(arr) + 100, 100)
# hist, _ = np.histogram(arr, bins=bin_edges)
# # 画柱状图
# plt.bar(bin_edges[:-1], hist, width=80, align='edge')
# # 设置图表标题和标签
# plt.title('CICIOT22 Dataset', fontsize=22)
# plt.xlabel('Packet Length', fontsize=22)
# plt.ylabel('Packet Number', fontsize=22)
# # 放大横纵坐标刻度标签的大小
# plt.tick_params(axis='x', labelsize=22)  # 放大横坐标刻度标签
# plt.tick_params(axis='y', labelsize=22)  # 放大纵坐标刻度标签
# # 定义一个新的ScalarFormatter类来移除乘号
# class NoMultiplyScalarFormatter(ScalarFormatter):
#     def _set_orderOfMagnitude(self, nothing):
#         self.orderOfMagnitude = 0
#     def get_offset(self):
#         return r'$10^{%d}$' % self.orderOfMagnitude if self.orderOfMagnitude else ''
# # 设置y轴的格式化器
# formatter = NoMultiplyScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# plt.gca().yaxis.set_major_formatter(formatter)
# # 显示科学计数法的次幂
# plt.gca().yaxis.get_offset_text().set_fontsize(22)
# plt.gca().yaxis.get_offset_text().set_position((0,1))
# plt.gca().yaxis.get_offset_text().set_verticalalignment('bottom')
# # 放大科学计数法标记的大小
# plt.gca().yaxis.get_offset_text().set_size(22)
# # 调整子图的边界，以便纵坐标标签有足够空间显示
# plt.subplots_adjust(bottom=0.15)
# plt.savefig('pck_lengths.png')
# # 显示图表
# plt.show()



# val_accurate_list = [0.9553675575209896, 0.9693135935397039, 0.976363519835929, 0.9836826251361918, 0.985464333781965, 0.9875280394795872, 0.9876177658142665, 0.9894892007947189, 0.9886303915913607, 0.9903864641415112, 0.9887970262129078, 0.9907581875280395, 0.9916939050182657, 0.9907453694802282, 0.991988720117926, 0.9932320707556239, 0.9933602512337371, 0.9925014420303788, 0.9927706210344165, 0.9938217009549446]
# iterations = range(1, len(val_accurate_list) + 1)
# import matplotlib.pyplot as plt
# # 绘制折线图
# plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
# plt.xlabel('Epoch', fontsize=22)
# plt.ylabel('Accuracy', fontsize=22)
# plt.title("CICIOT22 dataset", fontsize=22)
# # 放大横纵坐标刻度标签的大小
# plt.tick_params(axis='x', labelsize=18)  # 放大横坐标刻度标签
# plt.tick_params(axis='y', labelsize=22)  # 放大纵坐标刻度标签
# plt.xticks(range(0, len(val_accurate_list)+1, 2))  # 设置横坐标间距为1
# plt.ylim(0.8, 1.0)
# # 调整子图的边界，以便纵坐标标签有足够空间显示
# plt.subplots_adjust(left=0.2)
# plt.subplots_adjust(bottom=0.15)
# plt.grid(False)
# plt.savefig('Accurate_plot_CICIOT.png')
# plt.show()

# import matplotlib.pyplot as plt
# # 假设的迭代次数（横坐标）
# iterations = range(1, 21)
# # 假设的六种模型在不同迭代次数下的准确率（纵坐标）
# accuracy_model_AlexNet = [0.8900852400179453, 0.9222585400243543, 0.935858488752163, 0.9432545023392938, 0.9486765365634814, 0.9524706787156316, 0.9585336153303852, 0.9599436005896302, 0.9622252131000448, 0.9649170031404217, 0.9684035121451003, 0.9699929500737038, 0.9688521438184965, 0.9715182977632506, 0.9733512786002692, 0.9739409087995898, 0.9765814266487214, 0.9758892520669102, 0.9793244888803435, 0.9790424918284946]
# accuracy_model_GoogLeNet = [0.8188168941870153, 0.8614369031596488, 0.9116067422931488, 0.9298980965199, 0.9317951675959751, 0.9423572389925015, 0.948138178555406, 0.9511760558866884, 0.9401140806255207, 0.955547010190348, 0.9382554636928796, 0.9614176760879318, 0.9616227648529129, 0.9659937191565725, 0.9600205088764981, 0.9704672178427226, 0.9651861821444594, 0.9740178170864577, 0.9726078318272127, 0.9771069666089854]
# accuracy_model_MobileNet = [0.5050823559571878, 0.9479459078382363, 0.9391527270396719, 0.9736845478433634, 0.6605524578606679, 0.8005255399602641, 0.8812920592193809, 0.978017048003589, 0.9763891559315516, 0.9873101326667948, 0.9861949625072102, 0.9843876177658143, 0.988809844260719, 0.9886688457347946, 0.9853874254950971, 0.990014740754983, 0.9892584759341152, 0.9872075882843043, 0.9902198295199641, 0.9913990899186054]
# accuracy_model_VggNet = [0.9228353521758637, 0.9582772543741588, 0.9664423508299685, 0.9703774915080433, 0.9693648657309492, 0.9779914119079665, 0.9785554060116645, 0.983695443184003, 0.9873742229058514, 0.9844773441004935, 0.988604755495738, 0.9871306799974364, 0.989450746651285, 0.9911170928667564, 0.9879253989617381, 0.9910145484842658, 0.9913093635839262, 0.9888995705953983, 0.991706723066077, 0.9915400884445299]
# accuracy_model_SENet = [0.9529449464846503, 0.9536499391142729, 0.976363519835929, 0.9603922322630264, 0.9848490674870217, 0.9878356726270588, 0.9874254950970968, 0.9892584759341152, 0.9884124847785682, 0.9900660129462283, 0.9892328398384926, 0.9904761904761905, 0.9873742229058514, 0.9900531948984169, 0.9913606357751714, 0.9918733576876242, 0.9921169005960392, 0.9920015381657373, 0.9916939050182657, 0.9919502659744921]
# accuracy_model_ABCNet = [0.9553675575209896, 0.9693135935397039, 0.976363519835929, 0.9836826251361918, 0.985464333781965, 0.9875280394795872, 0.9876177658142665, 0.9894892007947189, 0.9886303915913607, 0.9903864641415112, 0.9887970262129078, 0.9907581875280395, 0.9916939050182657, 0.9907453694802282, 0.991988720117926, 0.9932320707556239, 0.9933602512337371, 0.9925014420303788, 0.9927706210344165, 0.9938217009549446]
# # 绘制折线图
# plt.figure(figsize=(10, 6))
# plt.plot(iterations, accuracy_model_AlexNet, label='AlexNet')
# plt.plot(iterations, accuracy_model_GoogLeNet, label='GoogLeNet')
# plt.plot(iterations, accuracy_model_MobileNet, label='MobileNet')
# plt.plot(iterations, accuracy_model_VggNet, label='VggNet')
# plt.plot(iterations, accuracy_model_SENet, label='SENet')
# plt.plot(iterations, accuracy_model_ABCNet, label='ABCNet')
#
# plt.xlabel('Epoch', fontsize=16)
# plt.ylabel('Accuracy', fontsize=16)
# plt.title('CICIOT dataset', fontsize=16)
# plt.legend()
# plt.grid(False)
#
# plt.savefig("zhexianduibitu.png")
# plt.show()
# Out:
# 文件夹Amazon Alexa Echo Dot 1创建成功
# 文件夹Amazon Alexa Echo Dot 2创建成功
# 文件夹Amazon Alexa Echo Spot创建成功
# 文件夹Amazon Alexa Echo Studio创建成功
# 文件夹Google Nest Mini创建成功
# 文件夹Sonos One Speaker创建成功
# 文件夹AMCREST WiFi Camera创建成功
# 文件夹Arlo Base Station创建成功
# 文件夹Arlo Q Camera创建成功
# 文件夹Borun Sichuan-AI Camera创建成功
# 文件夹DCS8000LHA1 D-Link Mini Camera创建成功
# 文件夹HeimVision Smart WiFi Camera创建成功
# 文件夹Home Eye Camera创建成功
# 文件夹Luohe Cam Dog创建成功
# 文件夹Nest Indoor Camera创建成功
# 文件夹Netatmo Camera创建成功
# 文件夹SIMCAM 1S (AMPAKTec)创建成功
# 文件夹Amazon Plug创建成功
# 文件夹Atomi Coffee Maker创建成功
# 文件夹Eufy HomeBase 2创建成功
# 文件夹Globe Lamp ESP B1680C创建成功
# 文件夹Gosund ESP 039AAF Socket创建成功
# 文件夹Gosund ESP 032979 Plug创建成功
# 文件夹Gosund ESP 10098F Socket创建成功
# 文件夹Gosund ESP 0C3994 Plug创建成功
# 文件夹Gosund ESP 1ACEE1  Socket创建成功
# 文件夹Gosund ESP 147FF9 Plug创建成功
# 文件夹Gosund ESP 10ACD8 Plug创建成功
# 文件夹HeimVision SmartLife Radio Lamp创建成功
# 文件夹Philips Hue Bridge创建成功
# 文件夹Ring Base Station AC 1236创建成功
# 文件夹iRobot Roomba创建成功
# 文件夹Smart Board创建成功
# ...
