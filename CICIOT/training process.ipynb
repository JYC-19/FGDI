# %%
import matplotlib.pyplot as plt

val_accurate_list = [0.9511510459392944, 0.9586495077932732, 0.9781583264971287, 0.9811961648892535, 0.9856183347005743, 0.98711802707137, 0.9854901558654635, 0.9895918785890074, 0.9894893355209188, 0.9827984003281378, 0.9904378589007383, 0.9880537325676785, 0.9913222928630024, 0.9888356234618539, 0.9897969647251845, 0.9933218826907301, 0.9912710213289582, 0.992091365873667, 0.9920657301066448, 0.9927066242821985]
iterations = range(1, len(val_accurate_list) + 1)

plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
plt.xlabel('Epoch', fontsize=22)
plt.ylabel('Accuracy', fontsize=22)
plt.title("CICIOT22 dataset", fontsize=22)
plt.tick_params(axis='x', labelsize=18)  
plt.tick_params(axis='y', labelsize=22) 
plt.xticks(range(0, len(val_accurate_list)+1, 2)) 
plt.ylim(0.8, 1.0)
plt.subplots_adjust(left=0.2)
plt.subplots_adjust(bottom=0.15)
plt.grid(False)
plt.savefig('Accurate_plot_CICIOT.png')
plt.show()
