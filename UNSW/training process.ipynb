# %%
import matplotlib.pyplot as plt

val_accurate_list = [0.9393219606996329, 0.9615633772403369, 0.9679982725113366, 0.9651479162167999, 0.9781256748002591, 0.9824659900669401, 0.9821636795508529, 0.9831569855322825, 0.9852083783200173, 0.9860289354351112, 0.9850356294536817, 0.9863744331677823, 0.9857914057438998, 0.9864392139926582, 0.9859209673936514, 0.9868926797667891, 0.9853379399697689, 0.9866119628589938, 0.9854027207946447, 0.9863528395594904]
iterations = range(1, len(val_accurate_list) + 1)
plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
plt.xlabel('Epoch', fontsize=22)
plt.ylabel('Accuracy', fontsize=22)
plt.title("UNSW dataset", fontsize=22)
plt.tick_params(axis='x', labelsize=18) 
plt.tick_params(axis='y', labelsize=22)  
plt.xticks(range(0, len(val_accurate_list)+1, 5)) 
plt.ylim(0.8, 1.0)
plt.subplots_adjust(left=0.2)
plt.subplots_adjust(bottom=0.15)
plt.grid(False)
plt.savefig('Accurate_plot_UNSW.png')
plt.show()
