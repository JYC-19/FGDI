# %%
import matplotlib.pyplot as plt

val_accurate_list = [0.9188979934189303, 0.9475234961395359, 0.9254790631653655, 0.9457169279738478, 0.9482117125836076, 0.9497171860550143, 0.9427489945587887, 0.9389638041163946, 0.9484482869862572, 0.9623846699787083, 0.9587070133557004, 0.9513301933458073, 0.9642557584360282, 0.9596102974385444, 0.9612017979654601, 0.9675893068370003, 0.9680624556422995, 0.9627502849646213, 0.9576101683979612, 0.9678688947674043]
iterations = range(1, len(val_accurate_list) + 1)
plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
plt.xlabel('Epoch', fontsize=22)
plt.ylabel('Accuracy', fontsize=22)
plt.title("UNSW dataset", fontsize=22)
plt.tick_params(axis='x', labelsize=18) 
plt.tick_params(axis='y', labelsize=22)  
plt.xticks(range(0, len(val_accurate_list)+1, 5)) 
plt.ylim(0.8, 1.0)
plt.subplots_adjust(left=0.2)
plt.subplots_adjust(bottom=0.15)
plt.grid(False)
plt.savefig('Accurate_plot_UNSW.png')
plt.show()
