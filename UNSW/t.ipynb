# %%
import os
def create_folders(folder_names):
    for folder_name in folder_names:
        folder_path = "features/npy/" + folder_name
        try:
            os.mkdir(folder_path)
            print("文件夹" + folder_name + "创建成功")
        except FileExistsError:
            print("文件夹" + folder_name + "已经创建")

dev_name = ['Amazon Echo', 'Netatmo Welcome', 'TP-Link Day Night Cloud camera', 'Samsung SmartCam', 'Dropcam', 'Insteon Camera', 'Withings Smart Baby Monitor', 'Belkin Wemo switch', 'TP-Link Smart plug', 'iHome', 'Belkin wemo motion sensor', 'NEST Protect smoke alarm', 'Netatmo weather station', 'Withings Smart scale', 'Blipcare Blood Pressure meter', 'Withings Aura smart sleep sensor', 'Light Bulbs LiFX Smart Bulb', 'Triby Speaker', 'PIX-STAR Photo-frame', 'HP Printer', 'Samsung Galaxy Tab', 'Nest Dropcam', 'Android Phone1', 'Laptop', 'MacBook', 'Android Phone2', 'IPhone']
create_folders(dev_name)

# def get_file_name_1(file_path):
#     file_names = os.listdir(file_path)
#     return file_names
#
# file_path = 'split_data'
# file_names = get_file_name_1(file_path)
# print(file_names)

# import os
# def count_files_in_folder(folder_path):
#     count = 0
#     for root, dirs, files in os.walk(folder_path):
#         count += len(files)
#     return count
#
# def count_files_in_subfolders(root_folder_path):
#     result = {}
#     for root, dirs, files in os.walk(root_folder_path):
#         num_files = count_files_in_folder(root)
#         result[root] = num_files
#     return result
#
# folder_path = "features/figure"
# subfolders_file_count = count_files_in_subfolders(folder_path)
#
# for folder, count in subfolders_file_count.items():
#     print("Folder:", folder)
#     print("Number of files:", count)
#     print("------------------")

# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib.ticker import ScalarFormatter
# arr = np.load("pck_lengths.npy")
# # 计算每个区间内数据包的数量
# bin_edges = np.arange(0, max(arr) + 100, 100)
# hist, _ = np.histogram(arr, bins=bin_edges)
# # 画柱状图
# plt.bar(bin_edges[:-1], hist, width=80, align='edge')
# # 设置图表标题和标签
# plt.title('UNSW Dataset', fontsize=22)
# plt.xlabel('Packet Length', fontsize=22)
# plt.ylabel('Packet Number', fontsize=22)
# # 放大横纵坐标刻度标签的大小
# plt.tick_params(axis='x', labelsize=22)  # 放大横坐标刻度标签
# plt.tick_params(axis='y', labelsize=22)  # 放大纵坐标刻度标签
# # 定义一个新的ScalarFormatter类来移除乘号
# class NoMultiplyScalarFormatter(ScalarFormatter):
#     def _set_orderOfMagnitude(self, nothing):
#         self.orderOfMagnitude = 0
#     def get_offset(self):
#         return r'$10^{%d}$' % self.orderOfMagnitude if self.orderOfMagnitude else ''
# # 设置y轴的格式化器
# formatter = NoMultiplyScalarFormatter(useMathText=True)
# formatter.set_scientific(True)
# formatter.set_powerlimits((-1,1))
# plt.gca().yaxis.set_major_formatter(formatter)
# # 显示科学计数法的次幂
# plt.gca().yaxis.get_offset_text().set_fontsize(22)
# plt.gca().yaxis.get_offset_text().set_position((0,1))
# plt.gca().yaxis.get_offset_text().set_verticalalignment('bottom')
# # 放大科学计数法标记的大小
# plt.gca().yaxis.get_offset_text().set_size(22)
# # 调整子图的边界，以便纵坐标标签有足够空间显示
# plt.subplots_adjust(bottom=0.15)
# plt.savefig('pck_lengths.png')
# # 显示图表
# plt.show()



# val_accurate_list = [0.9479162167998273, 0.9581299935219175, 0.9708054415892896, 0.9754264737637659, 0.977002807169078, 0.9806953141870006, 0.9807385014035845, 0.980954437486504, 0.9800475059382423, 0.9841718851220039, 0.9839775426473764, 0.9846253508961348, 0.9858993737853595, 0.9847765061541783, 0.9818613690347657, 0.9833729216152018, 0.9835672640898294, 0.9834161088317858, 0.9852299719283092, 0.9852515655366012]
# iterations = range(1, len(val_accurate_list) + 1)
# import matplotlib.pyplot as plt
# import numpy as np
# # 绘制折线图
# plt.plot(iterations, val_accurate_list, linestyle='-', linewidth=2.5)
# plt.xlabel('Epoch', fontsize=22)
# plt.ylabel('Accuracy', fontsize=22)
# plt.title("UNSW dataset", fontsize=22)
# # 放大横纵坐标刻度标签的大小
# plt.tick_params(axis='x', labelsize=18)  # 放大横坐标刻度标签
# plt.tick_params(axis='y', labelsize=22)  # 放大纵坐标刻度标签
# plt.xticks(range(0, len(val_accurate_list)+1, 5))  # 设置横坐标间距为1
# plt.ylim(0.8, 1.0)
# # 调整子图的边界，以便纵坐标标签有足够空间显示
# plt.subplots_adjust(left=0.2)
# plt.subplots_adjust(bottom=0.15)
# plt.grid(False)
# plt.savefig('Accurate_plot_UNSW.png')
# plt.show()


# str = "iterations:range(1, 21)train_accurate_list:[0.9000809716599191, 0.9628394062078273, 0.9715357624831309, 0.9768744939271256, 0.9794439946018894, 0.9809122807017544, 0.9831417004048583, 0.9843346828609987, 0.9852037786774629, 0.9856140350877193, 0.9862780026990553, 0.9867638326585695, 0.9873792172739542, 0.9876329284750337, 0.9878110661268557, 0.9888690958164642, 0.9889986504723347, 0.9898623481781377, 0.9903751686909582, 0.9907314439946019]val_accurate_list:[0.9479162167998273, 0.9581299935219175, 0.9708054415892896, 0.9754264737637659, 0.977002807169078, 0.9806953141870006, 0.9807385014035845, 0.980954437486504, 0.9800475059382423, 0.9841718851220039, 0.9839775426473764, 0.9846253508961348, 0.9858993737853595, 0.9847765061541783, 0.9818613690347657, 0.9833729216152018, 0.9835672640898294, 0.9834161088317858, 0.9852299719283092, 0.9852515655366012]f1_list:[0.8844716510730083, 0.9393200093492445, 0.9596276006874175, 0.9645138990689505, 0.9683634266881683, 0.9718462652274198, 0.9685921021036825, 0.9715664230328412, 0.9722229664416316, 0.9778395765003359, 0.9757804759137292, 0.9768715356042466, 0.9784573162993995, 0.9769557265120407, 0.9752252683047277, 0.9767563940048594, 0.9758332753878896, 0.975903339452374, 0.9760238013311505, 0.9759252730933162]recall_list:[0.8831693174019394, 0.9328168217279681, 0.9544468630585422, 0.9580936390701997, 0.9651442628764907, 0.9669522626699466, 0.9607082872302226, 0.9647643036346415, 0.9697567466234731, 0.9736899559267971, 0.970334505152759, 0.9709313045495107, 0.9773883901384814, 0.9715258176853488, 0.9709871095237729, 0.9738001466066232, 0.9758513984196296, 0.9731973139128393, 0.969918237265805, 0.9694365077328589]dev_list:['Amazon Echo', 'Android Phone1', 'Android Phone2', 'Belkin Wemo switch', 'Belkin wemo motion sensor', 'Blipcare Blood Pressure meter', 'Dropcam', 'HP Printer', 'IPhone', 'Insteon Camera', 'Laptop', 'Light Bulbs LiFX Smart Bulb', 'MacBook', 'NEST Protect smoke alarm', 'Nest Dropcam', 'Netatmo Welcome', 'Netatmo weather station', 'PIX-STAR Photo-frame', 'Samsung Galaxy Tab', 'Samsung SmartCam', 'TP-Link Day Night Cloud camera', 'TP-Link Smart plug', 'Triby Speaker', 'Withings Aura smart sleep sensor', 'Withings Smart Baby Monitor', 'Withings Smart scale', 'iHome']"
#
# arr = str.split("]")
# print(len(arr))
# for idx, i in enumerate(arr):
#     print(idx, i)










# import matplotlib.pyplot as plt
# # 假设的迭代次数（横坐标）
# iterations = range(1, 21)
# # 假设的六种模型在不同迭代次数下的准确率（纵坐标）
# accuracy_model_AlexNet = [0.8638954869358669, 0.9047505938242281, 0.9279853163463615, 0.9465990066940185, 0.9490174908227165, 0.9530770891816023, 0.9593824228028504, 0.9597063269272296, 0.9654070395163031, 0.9661412221982293, 0.9711293457136687, 0.9681710213776722, 0.9728784279853163, 0.9748866335564673, 0.9759231267544807, 0.9740012956164975, 0.9729648024184842, 0.9755776290218096, 0.9756640034549773, 0.9774562729432088]
# accuracy_model_GoogLeNet = [0.8052256532066508, 0.860742820125243, 0.8899589721442454, 0.9160872381774995, 0.917490822716476, 0.9260850788166702, 0.9323256316130425, 0.9566616281580652, 0.9568775642409847, 0.9621032174476355, 0.9637227380695315, 0.9649103865255885, 0.9651047290002159, 0.9705679118980781, 0.9715396242712158, 0.9729648024184842, 0.970654286331246, 0.9724033686028936, 0.9677175556035413, 0.9772835240768732]
# accuracy_model_MobileNet = [0.29233426905635934, 0.16542863312459513, 0.22787734830490175, 0.9287626862448716, 0.6780608939753833, 0.39652342906499677, 0.9416108831785791, 0.1491254588641762, 0.7083783200172749, 0.8845821636795509, 0.9578060893975383, 0.39732239257179874, 0.9707622543727057, 0.23610451306413302, 0.29326279421291296, 0.16536385229971928, 0.18054415892895703, 0.5965666162815807, 0.2679334916864608, 0.4216583891168214]
# accuracy_model_VggNet = [0.9336212481105592, 0.9534441805225653, 0.9633772403368603, 0.9708270351975815, 0.9699416972576117, 0.9706974735478299, 0.9786007341826819, 0.9776938026344202, 0.9788598574821853, 0.9804145972792053, 0.9797020082055712, 0.9805441589289571, 0.980155473979702, 0.9826387389332758, 0.9795292593392356, 0.9831569855322825, 0.9831137983156986, 0.9828762686244872, 0.9856402504858562, 0.9848196933707623]
# accuracy_model_SENet = [0.8798531634636148, 0.8400345497732671, 0.9756424098466854, 0.9698337292161521, 0.9002159360829195, 0.978557546966098, 0.9806305333621248, 0.98412869790542, 0.9832433599654502, 0.9832217663571583, 0.9853595335780609, 0.9836320449147052, 0.9818613690347657, 0.9799611315050745, 0.983308140790326, 0.9853811271863528, 0.9858129993521918, 0.985316346361477, 0.9850140358453897, 0.9857482185273159]
# accuracy_model_ABCNet = [0.9479162167998273, 0.9581299935219175, 0.9708054415892896, 0.9754264737637659, 0.977002807169078, 0.9806953141870006, 0.9807385014035845, 0.980954437486504, 0.9800475059382423, 0.9841718851220039, 0.9839775426473764, 0.9846253508961348, 0.9858993737853595, 0.9847765061541783, 0.9818613690347657, 0.9833729216152018, 0.9835672640898294, 0.9834161088317858, 0.9852299719283092, 0.9852515655366012]
# # 绘制折线图
# plt.figure(figsize=(10, 6))
# plt.plot(iterations, accuracy_model_AlexNet, label='AlexNet')
# plt.plot(iterations, accuracy_model_GoogLeNet, label='GoogLeNet')
# plt.plot(iterations, accuracy_model_MobileNet, label='MobileNet')
# plt.plot(iterations, accuracy_model_VggNet, label='VggNet')
# plt.plot(iterations, accuracy_model_SENet, label='SENet')
# plt.plot(iterations, accuracy_model_ABCNet, label='ABCNet')
#
# plt.xlabel('Epoch', fontsize=16)
# plt.ylabel('Accuracy', fontsize=16)
# plt.title('UNSW dataset', fontsize=16)
# plt.legend()
# plt.grid(False)
#
# # plt.savefig("zhexianduibitu.png")
# plt.show()
# Out:
# 文件夹Amazon Echo创建成功
# 文件夹Netatmo Welcome创建成功
# 文件夹TP-Link Day Night Cloud camera创建成功
# 文件夹Samsung SmartCam创建成功
# 文件夹Dropcam创建成功
# 文件夹Insteon Camera创建成功
# 文件夹Withings Smart Baby Monitor创建成功
# 文件夹Belkin Wemo switch创建成功
# 文件夹TP-Link Smart plug创建成功
# 文件夹iHome创建成功
# 文件夹Belkin wemo motion sensor创建成功
# 文件夹NEST Protect smoke alarm创建成功
# 文件夹Netatmo weather station创建成功
# 文件夹Withings Smart scale创建成功
# 文件夹Blipcare Blood Pressure meter创建成功
# 文件夹Withings Aura smart sleep sensor创建成功
# 文件夹Light Bulbs LiFX Smart Bulb创建成功
# 文件夹Triby Speaker创建成功
# 文件夹PIX-STAR Photo-frame创建成功
# 文件夹HP Printer创建成功
# 文件夹Samsung Galaxy Tab创建成功
# 文件夹Nest Dropcam创建成功
# 文件夹Android Phone1创建成功
# 文件夹Laptop创建成功
# 文件夹MacBook创建成功
# 文件夹Android Phone2创建成功
# 文件夹IPhone创建成功
