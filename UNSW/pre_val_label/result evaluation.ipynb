# %%
arr = ['Amazon Echo', 'Android Phone1', 'Android Phone2', 'Belkin Wemo switch', 'Belkin wemo motion sensor', 'Blipcare Blood Pressure meter', 'Dropcam', 'HP Printer', 'IPhone', 'Insteon Camera', 'Laptop', 'Light Bulbs LiFX Smart Bulb', 'MacBook', 'NEST Protect smoke alarm', 'Nest Dropcam', 'Netatmo Welcome', 'Netatmo weather station', 'PIX-STAR Photo-frame', 'Samsung Galaxy Tab', 'Samsung SmartCam', 'TP-Link Day Night Cloud camera', 'TP-Link Smart plug', 'Triby Speaker', 'Withings Aura smart sleep sensor', 'Withings Smart Baby Monitor', 'Withings Smart scale', 'iHome']
dic = {'Amazon Echo': 0, 'Android Phone1': 1, 'Android Phone2': 2, 'Belkin Wemo switch': 3, 'Belkin wemo motion sensor': 4, 'Blipcare Blood Pressure meter': 5, 'Dropcam': 6, 'HP Printer': 7, 'IPhone': 8, 'Insteon Camera': 9, 'Laptop': 10, 'Light Bulbs LiFX Smart Bulb': 11, 'MacBook': 12, 'NEST Protect smoke alarm': 13, 'Nest Dropcam': 14, 'Netatmo Welcome': 15, 'Netatmo weather station': 16, 'PIX-STAR Photo-frame': 17, 'Samsung Galaxy Tab': 18, 'Samsung SmartCam': 19, 'TP-Link Day Night Cloud camera': 20, 'TP-Link Smart plug': 21, 'Triby Speaker': 22, 'Withings Aura smart sleep sensor': 23, 'Withings Smart Baby Monitor': 24, 'Withings Smart scale': 25, 'iHome': 26}
from collections import defaultdict
import torch

def evaluate_metrics(predicted_labels, true_labels):
    label_metrics = defaultdict(dict)

    for label in true_labels:
        label_metrics[label]['actual_count'] = true_labels.count(label)
    for label in predicted_labels:
        label_metrics[label]['predicted_count'] = predicted_labels.count(label)

    for label in set(true_labels):
        true_positives = sum((p_label == label) and (t_label == label) for p_label, t_label in zip(predicted_labels, true_labels))
        false_positives = sum((p_label == label) and (t_label != label) for p_label, t_label in zip(predicted_labels, true_labels))
        false_negatives = sum((p_label != label) and (t_label == label) for p_label, t_label in zip(predicted_labels, true_labels))

        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        label_metrics[label]['precision'] = round(precision, 4)

        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        label_metrics[label]['recall'] = round(recall, 4)

        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        label_metrics[label]['f1_score'] = round(f1, 4)

    return label_metrics

predicted_labels = torch.load("best_pre_TrimSENet.pt").tolist()
true_labels = torch.load("best_val_TrimSENet.pt").tolist()
metrics = evaluate_metrics(predicted_labels, true_labels)

for label, metric in metrics.items():
    print(f"Label: {label}")
    print(f"Device: {[k for k, v in dic.items() if v == label]}")
    print(f"Actual Count: {metric['actual_count']}")
    print(f"Predicted Count: {metric['predicted_count']}")
    print(f"Precision: {metric['precision']:.4f}")
    print(f"Recall: {metric['recall']:.4f}")
    print(f"F1 Score: {metric['f1_score']:.4f}")
    print()

# import torch
# from sklearn.metrics import precision_score
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import f1_score
# from sklearn.metrics import recall_score

# arr = [("best_val_TrimSENet.pt","best_pre_TrimSENet.pt"),("best_val_AlexNet.pt","best_pre_AlexNet.pt"),
#        ("best_val_GoogLeNet.pt","best_pre_GoogLeNet.pt"),("best_val_MobileNet.pt","best_pre_MobileNet.pt"),
#        ("best_val_SENet.pt","best_pre_SENet.pt"),("best_val_VggNet.pt","best_pre_VggNet.pt")]

# for i in arr:
#     y_true_add, y_pred_add = i
#     y_true = torch.load(y_true_add).tolist()
#     y_pred = torch.load(y_pred_add).tolist()
#     precision_macro = precision_score(y_true, y_pred, average='macro')
#     recall = recall_score(y_true, y_pred, average='macro')
#     accuracy = accuracy_score(y_true, y_pred)
#     f1 = f1_score(y_true, y_pred, average='macro')
    
#     print(y_true_add.split("_")[2].split(".")[0])
#     print(f"Macro Precision: {precision_macro:.4f}")
#     print(f"recall: {recall:.4f}")
#     print(f"Accuracy: {accuracy:.4f}")
#     print(f"f1: {f1:.4f}")
# Out:
# Label: 0.0
# Device: ['Amazon Echo']
# Actual Count: 2000
# Predicted Count: 1993
# Precision: 0.9960
# Recall: 0.9925
# F1 Score: 0.9942
#
# Label: 1.0
# Device: ['Android Phone1']
# Actual Count: 1115
# Predicted Count: 1092
# Precision: 0.9716
# Recall: 0.9516
# F1 Score: 0.9615
#
# Label: 2.0
# Device: ['Android Phone2']
# Actual Count: 2000
# Predicted Count: 2013
# Precision: 0.9737
# Recall: 0.9800
# F1 Score: 0.9768
#
# Label: 3.0
# Device: ['Belkin Wemo switch']
# Actual Count: 2000
# Predicted Count: 1995
# Precision: 0.9995
# Recall: 0.9970
# F1 Score: 0.9982
#
# Label: 4.0
# Device: ['Belkin wemo motion sensor']
# Actual Count: 2000
# Predicted Count: 2024
# Precision: 0.9876
# Recall: 0.9995
# F1 Score: 0.9935
#
# Label: 5.0
# Device: ['Blipcare Blood Pressure meter']
# Actual Count: 21
# Predicted Count: 18
# Precision: 1.0000
# Recall: 0.8571
# F1 Score: 0.9231
#
# Label: 6.0
# Device: ['Dropcam']
# Actual Count: 2000
# Predicted Count: 1999
# Precision: 1.0000
# Recall: 0.9995
# F1 Score: 0.9997
#
# Label: 7.0
# Device: ['HP Printer']
# Actual Count: 2000
# Predicted Count: 1999
# Precision: 0.9995
# Recall: 0.9990
# F1 Score: 0.9992
#
# Label: 8.0
# Device: ['IPhone']
# Actual Count: 207
# Predicted Count: 185
# Precision: 0.9243
# Recall: 0.8261
# F1 Score: 0.8724
#
# Label: 9.0
# Device: ['Insteon Camera']
# Actual Count: 2000
# Predicted Count: 1989
# Precision: 0.9990
# Recall: 0.9935
# F1 Score: 0.9962
#
# Label: 10.0
# Device: ['Laptop']
# Actual Count: 2000
# Predicted Count: 1998
# Precision: 0.9995
# Recall: 0.9985
# F1 Score: 0.9990
#
# Label: 11.0
# Device: ['Light Bulbs LiFX Smart Bulb']
# Actual Count: 2000
# Predicted Count: 1997
# Precision: 1.0000
# Recall: 0.9985
# F1 Score: 0.9992
#
# Label: 12.0
# Device: ['MacBook']
# Actual Count: 2000
# Predicted Count: 2023
# Precision: 0.9827
# Recall: 0.9940
# F1 Score: 0.9883
#
# Label: 13.0
# Device: ['NEST Protect smoke alarm']
# Actual Count: 433
# Predicted Count: 435
# Precision: 0.9862
# Recall: 0.9908
# F1 Score: 0.9885
#
# Label: 14.0
# Device: ['Nest Dropcam']
# Actual Count: 2000
# Predicted Count: 1996
# Precision: 1.0000
# Recall: 0.9980
# F1 Score: 0.9990
#
# Label: 15.0
# Device: ['Netatmo Welcome']
# Actual Count: 2000
# Predicted Count: 1982
# Precision: 0.9960
# Recall: 0.9870
# F1 Score: 0.9915
#
# Label: 16.0
# Device: ['Netatmo weather station']
# Actual Count: 2000
# Predicted Count: 2040
# Precision: 0.9799
# Recall: 0.9995
# F1 Score: 0.9896
#
# Label: 17.0
# Device: ['PIX-STAR Photo-frame']
# Actual Count: 2000
# Predicted Count: 1930
# Precision: 0.9974
# Recall: 0.9625
# F1 Score: 0.9796
#
# Label: 18.0
# Device: ['Samsung Galaxy Tab']
# Actual Count: 2000
# Predicted Count: 1961
# Precision: 0.9995
# Recall: 0.9800
# F1 Score: 0.9896
#
# Label: 19.0
# Device: ['Samsung SmartCam']
# Actual Count: 2000
# Predicted Count: 1995
# Precision: 0.9985
# Recall: 0.9960
# F1 Score: 0.9972
#
# Label: 20.0
# Device: ['TP-Link Day Night Cloud camera']
# Actual Count: 2000
# Predicted Count: 1962
# Precision: 0.9969
# Recall: 0.9780
# F1 Score: 0.9874
#
# Label: 21.0
# Device: ['TP-Link Smart plug']
# Actual Count: 2000
# Predicted Count: 2336
# Precision: 0.8510
# Recall: 0.9940
# F1 Score: 0.9170
#
# Label: 22.0
# Device: ['Triby Speaker']
# Actual Count: 2000
# Predicted Count: 1925
# Precision: 0.9984
# Recall: 0.9610
# F1 Score: 0.9794
#
# Label: 23.0
# Device: ['Withings Aura smart sleep sensor']
# Actual Count: 2000
# Predicted Count: 1996
# Precision: 0.9990
# Recall: 0.9970
# F1 Score: 0.9980
#
# Label: 24.0
# Device: ['Withings Smart Baby Monitor']
# Actual Count: 2000
# Predicted Count: 2003
# Precision: 0.9985
# Recall: 1.0000
# F1 Score: 0.9993
#
# Label: 25.0
# Device: ['Withings Smart scale']
# Actual Count: 534
# Predicted Count: 510
# Precision: 0.9980
# Recall: 0.9532
# F1 Score: 0.9751
#
# Label: 26.0
# Device: ['iHome']
# Actual Count: 2000
# Predicted Count: 1914
# Precision: 0.9953
# Recall: 0.9525
# F1 Score: 0.9734
